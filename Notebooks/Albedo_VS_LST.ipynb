# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm

import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
#Import the data and rename the columns
df_1990 = pd.read_csv('1990.csv').rename(columns={'Unnamed: 0' : 'Albedo', '[x][0]' : 'LST', '[x][1]':'Intercept'})
df_2000 = pd.read_csv('2000.csv').rename(columns={'Unnamed: 0' : 'Albedo', '[x][0]' : 'LST', '[x][1]':'Intercept'})
df_2014 = pd.read_csv('2014.csv').rename(columns={'Unnamed: 0' : 'Albedo', '[x][0]' : 'LST', '[x][1]':'Intercept'})
df_2024 = pd.read_csv('2024.csv').rename(columns={'Unnamed: 0' : 'Albedo', '[x][0]' : 'LST', '[x][1]':'Intercept'})

# %%
#Select the data for the correlation analysis\ Performing Ordinary Least Squares
############## Year 1990
X_1990 = df_1990['Albedo']
Y_1990 = df_1990['LST']

X_1990 = sm.add_constant(X_1990)
model_1990 = sm.OLS(Y_1990,X_1990).fit()
summary_1990 = model_1990.summary()

########### Year 2000 
X_2000 = df_2000['Albedo']
Y_2000 = df_2000['LST']

X_2000 = sm.add_constant(X_2000)
model_2000 = sm.OLS(Y_2000,X_2000).fit()
summary_2000 = model_2000.summary()

################ Year 2014
X_2014 = df_2014['Albedo']
Y_2014 = df_2014['LST']

X_2014 = sm.add_constant(X_2014)
model_2014 = sm.OLS(Y_2014,X_2014).fit()
summary_2014 = model_2014.summary()

################ Year 2024
X_2024 = df_2024['Albedo']
Y_2024 = df_2024['LST']

X_2024 = sm.add_constant(X_2024)
model_2024 = sm.OLS(Y_2024,X_2024).fit()
summary_2024 = model_2024.summary()

# %%
# Extract relevant statistics from each model summary
data = {
    'Year': ['1990', '2000', '2014', '2024'],
    'R-squared': [model_1990.rsquared, model_2000.rsquared, model_2014.rsquared, model_2024.rsquared],
    'Intercept': [model_1990.params.iloc[0], model_2000.params.iloc[0], model_2014.params.iloc[0], model_2024.params.iloc[0]],
    'Slope': [model_1990.params.iloc[1], model_2000.params.iloc[1], model_2014.params.iloc[1], model_2024.params.iloc[1]],
    'P-value': [model_1990.pvalues.iloc[1], model_2000.pvalues.iloc[1], model_2014.pvalues.iloc[1], model_2024.pvalues.iloc[1]]
}

# Create a DataFrame
summary_df = pd.DataFrame(data)

# Print the DataFrame
summary_df
# Out:
#    Year  R-squared  Intercept      Slope       P-value
# 0  1990   0.000004  58.168349  -0.265506  9.520555e-01
# 1  2000   0.104052  40.884301  50.164155  1.199641e-25
# 2  2014   0.000282  62.585123  -1.936039  5.960918e-01
# 3  2024   0.003348  64.823291  -4.541324  6.741518e-02

# %%
# Function to fit model and get regression line data
def fit_model(df):
    X = df['Albedo']
    Y = df['LST']
    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()
    
    # Generate regression line data
    x_range = np.linspace(X['Albedo'].min(), X['Albedo'].max(), 1000)
    y_range = model.predict(sm.add_constant(x_range))
    
    return x_range, y_range, model

# Fit models for each year and get regression line data
x_range_1990, y_range_1990, model_1990 = fit_model(df_1990)
x_range_2000, y_range_2000, model_2000 = fit_model(df_2000)
x_range_2014, y_range_2014, model_2014 = fit_model(df_2014)
x_range_2024, y_range_2024, model_2024 = fit_model(df_2024)

# Create subplots
fig = make_subplots(rows=2, cols=2, subplot_titles=('1990 (R²=0.000004)', '2000 (R²=0.104052)', '2014 (R²=0.000282)', '2024 (R²=0.003348)'))

# Add scatter and regression line for each year
# Year 1990
fig.add_trace(go.Scatter(
    x=df_1990['Albedo'],
    y=df_1990['LST'],
    mode='markers',
    name='Data Points',
    marker=dict(size=2, color='blue')
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=x_range_1990,
    y=y_range_1990,
    mode='lines',
    name='Regression Line 1990',
    line=dict(color='red')
), row=1, col=1)

# Year 2000
fig.add_trace(go.Scatter(
    x=df_2000['Albedo'],
    y=df_2000['LST'],
    mode='markers',
    marker=dict(size=2, color='blue')
), row=1, col=2)

fig.add_trace(go.Scatter(
    x=x_range_2000,
    y=y_range_2000,
    mode='lines',
    name='Regression Line 2000',
    line=dict(color='red')
), row=1, col=2)

# Year 2014
fig.add_trace(go.Scatter(
    x=df_2014['Albedo'],
    y=df_2014['LST'],
    mode='markers',
    marker=dict(size=2, color='blue')
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=x_range_2014,
    y=y_range_2014,
    mode='lines',
    name='Regression Line 2014',
    line=dict(color='red')
), row=2, col=1)

# Year 2024
fig.add_trace(go.Scatter(
    x=df_2024['Albedo'],
    y=df_2024['LST'],
    mode='markers',
    marker=dict(size=2, color='blue')
), row=2, col=2)

fig.add_trace(go.Scatter(
    x=x_range_2024,
    y=y_range_2024,
    mode='lines',
    name='Regression Line 2024',
    line=dict(color='red')
), row=2, col=2)

# Update layout
fig.update_layout(
    xaxis_title="Albedo",
    yaxis_title="LST",
    title='Correlation between Albedo and LST for 1990, 2000, 2014, & 2024',
    height=600,
    width=800,
    showlegend=False,
    template='plotly_white'
)

# Show the plot
fig.show()
